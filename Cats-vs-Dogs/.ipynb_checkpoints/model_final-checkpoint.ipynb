# %%
import tensorflow as tf

# %% [markdown]
# # Cats vs Dogs

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import cv2
from tensorflow.keras import layers
import os
import PIL
from PIL import Image

import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Rescaling
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator 



import numpy as np
from glob import glob
import os
import matplotlib.pyplot as plt

# %%
img = cv2.imread("PetImages/Dog/1616.jpg")
type(img)
# Out:
# numpy.ndarray

# %%
# path_cat = 'PetImages/Cat/'
current_dir = os.getcwd()
path_cat = 'PetImages/Cat/'
path_dog = 'PetImages/Dog/'
path_data = 'PetImages/'
path_graycat = 'PetImages/Cat/Cat/'
path_graydog = 'PetImages/Dog/Dog/'

error_dogs = ['10158.jpg','10747.jpg','11410.jpg','11702.jpg','11853.jpg','1866.jpg','2688.jpg','3136.jpg','3588.jpg','5604.jpg','6059.jpg','6718.jpg','8133.jpg','7459.jpg','8730.jpg','10401.jpg','10797.jpg','11675.jpg','11849.jpg','1308.jpg','2384.jpg','2877.jpg','3288.jpg','4367.jpg','6238.jpg','7112.jpg','7369.jpg','7969.jpg','9188.jpg','7133.jpg','Thumbs.db']
error_cats = ['10125.jpg','10501.jpg','11210.jpg','11874.jpg','140.jpg','3300.jpg','4833.jpg','660.jpg','7978.jpg','850.jpg','9565.jpg','10404.jpg','10820.jpg','11565.jpg','11935.jpg','2663.jpg','3491.jpg','5553.jpg','666.jpg','8470.jpg','9171.jpg','9778.jpg','936.jpg','7968.jpg','Thumbs.db']

# %% [markdown]
# Coś o samym zbiorze?? ile zdjec kotow ile psow

# %% [markdown]
# Coś o data cleaning??

# %%
#część zdjęć ma mniejszy rozmiar niż te 100x100, które wpisuję w modelu. Poniżej znajduję takie zdjęcia, wrzucam je do list

# min_width = float('inf')
# min_height = float('inf')

# def small_images_generator(folder_path):
#     for filename in os.listdir(folder_path):
#         image_path = os.path.join(folder_path, filename)
#         try:
#             image = Image.open(image_path)
#             width, height = image.size
#             if width < 100 or height < 100:
#                 yield filename
#         except (IOError, OSError):
#                 print(f"Nie można otworzyć pliku: {image_path}")    

# small_cats = []
# small_dogs = []
# for filename in small_images_generator(path_cat):
#     small_cats.append(filename)

# for filename in small_images_generator(path_dog):
#     small_dogs.append(filename)

# print(len(small_cats))
# print(len(small_dogs))

# %%
# zmieniamy kanał na RGM dla zdjęć, które miały inny kanał

# for filename in os.listdir(path_dog):
#     image_path = os.path.join(path_dog, filename)
#     try:
#         image = Image.open(image_path)
#         if channels not in ['3']:
#             image_rgb = image.convert("RGB")
#     except (IOError, OSError):
#         print(f"Nie można otworzyć pliku: {image_path}")

# for filename in os.listdir(path_cat):
#     image_path = os.path.join(path_cat, filename)
#     try:
#         image = Image.open(image_path)
#         if channels not in ['3']:
#             image_rgb = image.convert("RGB")
#     except (IOError, OSError):
#         print(f"Nie można otworzyć pliku: {image_path}")

# %%
def removing_files(list_of_files_to_delete,folder_path):
    for file in list_of_files_to_delete:
        file = folder_path + file
        try:
            os.remove(file)
            print(f"Plik '{file}' usunięty")
        except FileNotFoundError:
            print(f"Nie znaleziono pliku '{file}'")
        except PermissionError:
            print(f"PermissionError: '{file}'.")
        except Exception as e:
            print(f"Exception: '{file}': {str(e)}")

# %%
# tutaj usuwam pliki z tych list: error_dogs, error_cats, small_cats, small_dogs,
# dla każdej listy trzeba odpowiednio dobrać ścieżkę: path_cat, path_dog

# removing_files(error_dogs,path_dog)
# removing_files(small_dogs,path_dog)
# removing_files(error_cats,path_cat)
# removing_files(small_cats,path_cat)

# %%
# poniższe pętle konwertują wszystkie zdjęcia na kanał 3 - 'RGB'. Miałem problemy z fitowaniem, więc chciałem się upewnić, że wszystko jest 'RGB'

# for filename in os.listdir(path_dog):
#     image_path = os.path.join(path_dog, filename)
#     try:
#         image = Image.open(image_path)
#         image_gray = image.convert("RGB")
#         image_gray.save(image_path)
#     except (IOError, OSError):
#         print(f"Nie można otworzyć pliku: {image_path}")

# for filename in os.listdir(path_cat):
#     image_path = os.path.join(path_cat, filename)
#     try:
#         image = Image.open(image_path)
#         image_gray = image.convert("RGB")
#         image_gray.save(image_path)
#     except (IOError, OSError):
#         print(f"Nie można otworzyć pliku: {image_path}")

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    path_data,
    labels='inferred',
    batch_size=32,
    image_size=(100, 100),
    validation_split=0.2,
    subset = 'training',
    seed=123,
    # class_names=['Cat', 'Dog']
)
# Out:
# Found 24776 files belonging to 2 classes.
# Using 19821 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    path_data,
    labels='inferred',
    batch_size=32,
    image_size=(100, 100),
    validation_split=0.2,
    subset = 'validation',
    seed=123,
    # class_names=['Cat', 'Dog']
)
# Out:
# Found 24776 files belonging to 2 classes.
# Using 4955 files for validation.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = train_ds.map(lambda x, y: (x, tf.one_hot(y, depth=2)))
val_ds = val_ds.map(lambda x, y: (x, tf.one_hot(y, depth=2)))

# %%
# data = []
# labels = []

# %%
# cat_images = os.listdir(path_cat)
# for image_name in cat_images:
#     try:
#         image_path = os.path.join(path_cat, image_name)
#         image = cv2.imread(image_path)
#         image = cv2.resize(image, (150, 150))
#         image = image.astype('float32') / 255.0
#         data.append(image)
#         labels.append('cat')
#     except:
#         pass

# %%
# dog_images = os.listdir(path_dog)
# for image_name in dog_images:
#     try:
#         image_path = os.path.join(path_dog, image_name)
#         image = cv2.imread(image_path)
#         image = cv2.resize(image, (150, 150))
#         image = image.astype('float32') / 255.0
#         data.append(image)
#         labels.append('dog')
#     except:
#         pass

# %%
# model = Sequential()
# model.add(Rescaling(1./255, input_shape=(100, 100, 3)))
# model.add(Conv2D(16, 3, padding='same', activation='relu'))
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.3))
# model.add(Conv2D(32, 3, padding='same', activation='relu'))
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.3))
# model.add(Conv2D(64, 3, padding='same', activation='relu'))
# model.add(MaxPooling2D((2, 2)))
# model.add(Dropout(0.3))
# model.add(Conv2D(64, 3, padding='same', activation='relu'))
# model.add(MaxPooling2D((2, 2)))

# model.add(Flatten())
# # Dodawanie warstw gęstych
# model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.3))
# model.add(Dense(16, activation='relu'))
# model.add(Dense(2, activation='softmax'))  # Warstwa wyjściowa z dwoma neuronami (kot i pies)

# %%
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# _________________________________________________________________
#  Layer (type)                Output Shape              Param
# ================================================================
#   rescaling (Rescaling)      (None, 100, 100, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 16)       0
#  )
#
#  dropout (Dropout)           (None, 50, 50, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 25, 25, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 32)                73760
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 134,834
# Trainable params: 134,834
# Non-trainable params: 0
# _________________________________________________________________

# %%
# print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 100, 100, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 16)       0
#  )
#
#  dropout (Dropout)           (None, 50, 50, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 25, 25, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 32)                73760
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 134,834
# Trainable params: 134,834
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# # EarlyStopping - trzeba dodac w komórce niżej callback=es jesli chcemy go uzyc
# es = tf.keras.callbacks.EarlyStopping(
#     monitor="val_loss",
#     min_delta=0.01,
#     patience=4
# )

# %%
# 200 epoch, 0.3- dropout

# %%
# results = model.fit(train_ds, epochs=200, validation_data=val_ds)
# Out:
# Epoch 1/200
# 620/620 [==============================] - 35s 49ms/step - loss: 0.6847 - accuracy: 0.5461 - val_loss: 0.6528 - val_accuracy: 0.6157
# Epoch 2/200
# 620/620 [==============================] - 36s 58ms/step - loss: 0.6046 - accuracy: 0.6689 - val_loss: 0.5557 - val_accuracy: 0.7201
# Epoch 3/200
# 620/620 [==============================] - 36s 57ms/step - loss: 0.5379 - accuracy: 0.7293 - val_loss: 0.5403 - val_accuracy: 0.7094
# Epoch 4/200
# 620/620 [==============================] - 36s 58ms/step - loss: 0.4872 - accuracy: 0.7635 - val_loss: 0.4665 - val_accuracy: 0.7711
# Epoch 5/200
# 620/620 [==============================] - 32s 52ms/step - loss: 0.4525 - accuracy: 0.7910 - val_loss: 0.4449 - val_accuracy: 0.8089
# Epoch 6/200
# 620/620 [==============================] - 34s 55ms/step - loss: 0.4362 - accuracy: 0.7984 - val_loss: 0.4786 - val_accuracy: 0.7560
# Epoch 7/200
# 620/620 [==============================] - 31s 50ms/step - loss: 0.4127 - accuracy: 0.8115 - val_loss: 0.4092 - val_accuracy: 0.8032
# Epoch 8/200
# 620/620 [==============================] - 31s 50ms/step - loss: 0.3989 - accuracy: 0.8191 - val_loss: 0.4123 - val_accuracy: 0.8133
# Epoch 9/200
# 620/620 [==============================] - 30s 48ms/step - loss: 0.3845 - accuracy: 0.8270 - val_loss: 0.3856 - val_accuracy: 0.8262
# Epoch 10/200
# 620/620 [==============================] - 29s 47ms/step - loss: 0.3757 - accuracy: 0.8347 - val_loss: 0.3805 - val_accuracy: 0.8448
# Epoch 11/200
# 620/620 [==============================] - 37s 59ms/step - loss: 0.3655 - accuracy: 0.8384 - val_loss: 0.3742 - val_accuracy: 0.8252
# Epoch 12/200
# 620/620 [==============================] - 30s 49ms/step - loss: 0.3455 - accuracy: 0.8478 - val_loss: 0.3689 - val_accuracy: 0.8373
# Epoch 13/200
# 620/620 [==============================] - 32s 51ms/step - loss: 0.3428 - accuracy: 0.8518 - val_loss: 0.3499 - val_accuracy: 0.8430
# Epoch 14/200
# 620/620 [==============================] - 30s 49ms/step - loss: 0.3269 - accuracy: 0.8596 - val_loss: 0.3314 - val_accuracy: 0.8601
# Epoch 15/200
# 620/620 [==============================] - 31s 50ms/step - loss: 0
200
# 620/620 [==============================] - 31s 50ms/step - loss: 0.1010 - accuracy: 0.9609 - val_loss: 0.2557 - val_accuracy: 0.9049
# Epoch 195/200
# 620/620 [==============================] - 32s 52ms/step - loss: 0.0968 - accuracy: 0.9635 - val_loss: 0.2735 - val_accuracy: 0.9021
# Epoch 196/200
# 620/620 [==============================] - 31s 50ms/step - loss: 0.0994 - accuracy: 0.9611 - val_loss: 0.2626 - val_accuracy: 0.9007
# Epoch 197/200
# 620/620 [==============================] - 38s 62ms/step - loss: 0.0971 - accuracy: 0.9643 - val_loss: 0.2507 - val_accuracy: 0.8981
# Epoch 198/200
# 620/620 [==============================] - 31s 49ms/step - loss: 0.0988 - accuracy: 0.9621 - val_loss: 0.2489 - val_accuracy: 0.9021
# Epoch 199/200
# 620/620 [==============================] - 33s 53ms/step - loss: 0.1004 - accuracy: 0.9622 - val_loss: 0.2770 - val_accuracy: 0.9003
# Epoch 200/200
# 620/620 [==============================] - 30s 49ms/step - loss: 0.0990 - accuracy: 0.9613 - val_loss: 0.2692 - val_accuracy: 0.8981

# %%
# # Generate predictions for the validation dataset
# y_pred = np.argmax(model.predict(val_ds), axis=1)

# # Get true labels for the validation dataset
# y_test = np.concatenate([y for x, y in val_ds], axis=0)
# y_test = np.argmax(y_test, axis=1)

# # Print the classification report
# print(classification_report(y_test, y_pred, target_names=["Dog", "Cat"]))
# Out:
# 155/155 [==============================] - 2s 11ms/step
#               precision    recall  f1-score   support
#
#          Dog       0.87      0.93      0.90      2429
#          Cat       0.93      0.86      0.90      2526
#
#     accuracy                           0.90      4955
#    macro avg       0.90      0.90      0.90      4955
# weighted avg       0.90      0.90      0.90      4955

# %% [markdown]
#               precision    recall  f1-score   support
#
#          Dog       0.87      0.93      0.90      2429
#          Cat       0.93      0.86      0.90      2526
#
#     accuracy                           0.90      4955
#    macro avg       0.90      0.90      0.90      4955
# weighted avg       0.90      0.90      0.90      4955

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# plt.plot(results.history["loss"])
# plt.plot(results.history["val_loss"],'red')
# plt.title("loss")
# plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# plt.plot(results.history["accuracy"])
# plt.plot(results.history["val_accuracy"],'red')
# plt.title("accuracy")
# plt.show()

# %%
from tensorflow.keras.applications.resnet_v2 import ResNet50V2, preprocess_input
from tensorflow.keras.models import Model, Sequential

# %%
IMAGE_SIZE = [100,100]
resent_model = ResNet50V2(include_top=False, weights='imagenet', input_shape=IMAGE_SIZE + [3])

for layer in resent_model.layers:
    layer.trainable = False

resent_model.summary()

x = Conv2D(128, (3, 3), activation='relu')(resent_model.output)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(100,activation='relu')(x)
x = Dense(6,activation='sigmoid')(x)

model = Model(inputs=resent_model.input, outputs=x)

model.summary()


model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics = ['accuracy']
)

# %%
IMAGE_SIZE = [100,100]

# %%
resent_model = ResNet50V2(include_top=False, weights='imagenet', input_shape=IMAGE_SIZE + [3])

# %%
for layer in resent_model.layers:
    layer.trainable = False

# %%
resent_model.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 106, 106, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 50, 50, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 52, 52, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 25, 25, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 25, 25, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 25, 25, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 25, 25, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 27, 27, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 25, 25, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 25, 25, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 25, 25, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 25, 25, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 25, 25, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 27, 27, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 25, 25, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 25, 25, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 25, 25, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 25, 25, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 25, 25, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 27, 27, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 13, 13, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 13, 13, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 13, 13, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 13, 13, 256)  0          ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 13, 13, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 13, 13, 256)  0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 13, 13, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 13, 13, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 13, 13, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 15, 15, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 13, 13, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 13, 13, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 13, 13, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 13, 13, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 13, 13, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 13, 13, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 15, 15, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 13, 13, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 13, 13, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 13, 13, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 13, 13, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 13, 13, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 15, 15, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 13, 13, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 13, 13, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 13, 13, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 13, 13, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 13, 13, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 15, 15, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 7, 7, 128)    147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 7, 7, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 512)   0           ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 7, 7, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 7, 7, 512)    0           ['max_pooling2d_7[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 7, 7, 512)   2048        ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 7, 7, 512)   0           ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 7, 256)    131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 7, 7, 1024)   525312      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block1_0_conv[0][0]',
#                                                                   'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block1_out[0][0]']
#  ormalization)
#
#  conv4_block2_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block2_preact_bn[0][0]']
#  vation)
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block2_out[0][0]']
#  ormalization)
#
#  conv4_block3_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block3_preact_bn[0][0]']
#  vation)
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block3_out[0][0]']
#  ormalization)
#
#  conv4_block4_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block4_preact_bn[0][0]']
#  vation)
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block4_out[0][0]']
#  ormalization)
#
#  conv4_block5_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block5_preact_bn[0][0]']
#  vation)
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block5_out[0][0]']
#  ormalization)
#
#  conv4_block6_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block6_preact_bn[0][0]']
#  vation)
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 4, 4, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 4, 4, 1024)   0           ['max_pooling2d_8[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 4, 4, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 4, 4, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 4, 4, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 6, 6, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 4, 4, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 4, 4, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 4, 4, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 4, 4, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 4, 4, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 6, 6, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 4, 4, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 4, 4, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 4, 4, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 4, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 6, 6, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 4, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 4, 4, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 4, 4, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 4, 4, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 0
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
x = Conv2D(128, (3, 3), activation='relu')(resent_model.output)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(100,activation='relu')(x)
x = Dense(2,activation='sigmoid')(x)

model = Model(inputs=resent_model.input, outputs=x)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 106, 106, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 50, 50, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 52, 52, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 25, 25, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 25, 25, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 25, 25, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 25, 25, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 27, 27, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 25, 25, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 25, 25, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 25, 25, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 25, 25, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 25, 25, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 27, 27, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 25, 25, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 25, 25, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 25, 25, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 25, 25, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 25, 25, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 25, 25, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 25, 25, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 25, 25, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 27, 27, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 13, 13, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 13, 13, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 13, 13, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 13, 13, 256)  0          ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 13, 13, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 13, 13, 256)  0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 13, 13, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 13, 13, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 13, 13, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 15, 15, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 13, 13, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 13, 13, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 13, 13, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 13, 13, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 13, 13, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 13, 13, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 15, 15, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 13, 13, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 13, 13, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 13, 13, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 13, 13, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 13, 13, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 15, 15, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 13, 13, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 13, 13, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 13, 13, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 13, 13, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 13, 13, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 13, 13, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 13, 13, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 13, 13, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 15, 15, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 7, 7, 128)    147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 7, 7, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 512)   0           ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 7, 7, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 7, 7, 512)    0           ['max_pooling2d_7[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 7, 7, 512)   2048        ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 7, 7, 512)   0           ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 7, 7, 256)    131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 7, 7, 1024)   525312      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block1_0_conv[0][0]',
#                                                                   'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block1_out[0][0]']
#  ormalization)
#
#  conv4_block2_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block2_preact_bn[0][0]']
#  vation)
#
#  conv4_block2_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block2_out[0][0]']
#  ormalization)
#
#  conv4_block3_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block3_preact_bn[0][0]']
#  vation)
#
#  conv4_block3_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block3_out[0][0]']
#  ormalization)
#
#  conv4_block4_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block4_preact_bn[0][0]']
#  vation)
#
#  conv4_block4_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block4_out[0][0]']
#  ormalization)
#
#  conv4_block5_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block5_preact_bn[0][0]']
#  vation)
#
#  conv4_block5_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_out (Add)         (None, 7, 7, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block5_out[0][0]']
#  ormalization)
#
#  conv4_block6_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv4_block6_preact_bn[0][0]']
#  vation)
#
#  conv4_block6_1_conv (Conv2D)   (None, 7, 7, 256)    262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 9, 9, 256)   0           ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 4, 4, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 4, 4, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 4, 4, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 4, 4, 1024)   0           ['max_pooling2d_8[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 4, 4, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 4, 4, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 4, 4, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 6, 6, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 4, 4, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 4, 4, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 4, 4, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 4, 4, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 4, 4, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 6, 6, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 4, 4, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 4, 4, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 4, 4, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 4, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 6, 6, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 4, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 4, 4, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 4, 4, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 4, 4, 2048)   0           ['post_bn[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 2, 2, 128)    2359424     ['post_relu[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 1, 1, 128)   0           ['conv2d_3[0][0]']
#
#  flatten_3 (Flatten)            (None, 128)          0           ['max_pooling2d_9[0][0]']
#
#  dense_6 (Dense)                (None, 100)          12900       ['flatten_3[0][0]']
#
#  dense_7 (Dense)                (None, 6)            606         ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 25,937,730
# Trainable params: 2,372,930
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics = ['accuracy']
)

# %%
# EarlyStopping - trzeba dodac w komórce niżej callback=es jesli chcemy go uzyc
es = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.01,
    patience=4
)

# %%
hist = model.fit(train_ds,
                validation_data = val_ds,
                epochs = 20,
                steps_per_epoch=len(train_ds),
                validation_steps=len(val_ds))
# Out:
# Epoch 1/20
# 620/620 [==============================] - 202s 321ms/step - loss: 11.9813 - accuracy: 0.6441 - val_loss: 1.7050 - val_accuracy: 0.7045
# Epoch 2/20
# 620/620 [==============================] - 191s 308ms/step - loss: 1.2884 - accuracy: 0.7233 - val_loss: 0.7874 - val_accuracy: 0.7011
# Epoch 3/20
# 620/620 [==============================] - 192s 309ms/step - loss: 0.5642 - accuracy: 0.7454 - val_loss: 0.5559 - val_accuracy: 0.7348
# Epoch 4/20
# 620/620 [==============================] - 192s 309ms/step - loss: 0.5035 - accuracy: 0.7604 - val_loss: 0.5460 - val_accuracy: 0.7348
# Epoch 5/20
# 620/620 [==============================] - 192s 309ms/step - loss: 0.6890 - accuracy: 0.7272 - val_loss: 0.6488 - val_accuracy: 0.7312
# Epoch 6/20
# 620/620 [==============================] - 211s 341ms/step - loss: 0.7750 - accuracy: 0.7151 - val_loss: 0.5843 - val_accuracy: 0.6985
# Epoch 7/20
# 620/620 [==============================] - 214s 345ms/step - loss: 0.5867 - accuracy: 0.7322 - val_loss: 0.5992 - val_accuracy: 0.6727
# Epoch 8/20
# 620/620 [==============================] - 199s 322ms/step - loss: 0.6297 - accuracy: 0.6325 - val_loss: 0.6948 - val_accuracy: 0.5098
# Epoch 9/20
# 620/620 [==============================] - 195s 314ms/step - loss: 0.6937 - accuracy: 0.4976 - val_loss: 0.6931 - val_accuracy: 0.5096
# Epoch 10/20
# 620/620 [==============================] - 191s 309ms/step - loss: 0.6930 - accuracy: 0.4989 - val_loss: 0.6933 - val_accuracy: 0.4902
# Epoch 11/20
# 620/620 [==============================] - 193s 311ms/step - loss: 0.6930 - accuracy: 0.5013 - val_loss: 0.6949 - val_accuracy: 0.4908
# Epoch 12/20
# 620/620 [==============================] - 191s 309ms/step - loss: 0.6930 - accuracy: 0.5029 - val_loss: 0.6932 - val_accuracy: 0.4902
# Epoch 13/20
# 620/620 [==============================] - 193s 311ms/step - loss: 0.6930 - accuracy: 0.5037 - val_loss: 0.6933 - val_accuracy: 0.4902
# Epoch 14/20
# 620/620 [==============================] - 194s 313ms/step - loss: 0.6930 - accuracy: 0.4966 - val_loss: 0.6933 - val_accuracy: 0.4902
# Epoch 15/20
# 620/620 [==============================] - 192s 309ms/step - loss: 0.6930 - accuracy: 0.4994 - val_loss: 0.6932 - val_accuracy: 0.4902
# Epoch 16/20
# 620/620 [==============================] - 191s 308ms/step - loss: 0.6930 - accuracy: 0.5065 - val_loss: 0.6943 - val_accuracy: 0.5094
# Epoch 17/20
# 620/620 [==============================] - 192s 310ms/step - loss: 0.6934 - accuracy: 0.4994 - val_loss: 0.6931 - val_accuracy: 0.5096
# Epoch 18/20
# 620/620 [==============================] - 192s 310ms/step - loss: 0.6930 - accuracy: 0.4996 - val_loss: 0.6933 - val_accuracy: 0.4902
# Epoch 19/20
# 620/620 [==============================] - 194s 312ms/step - loss: 0.6930 - accuracy: 0.5033 - val_loss: 0.6931 - val_accuracy: 0.5096
# Epoch 20/20
# 620/620 [==============================] - 192s 309ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6934 - val_accuracy: 0.4902

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 from sklearn.metrics import precision_score, recall_score, f1_score
# ----> 3 precision = precision_score(y_true, y_pred, zero_division=1)
#       4 recall = recall_score(y_true, y_pred, zero_division=1)
#       5 f1 = f1_score(y_true, y_pred, zero_division=1)
#
# NameError: name 'y_true' is not defined

# %%
# Generate predictions for the validation dataset
y_pred = np.argmax(model.predict(val_ds), axis=1)

# Get true labels for the validation dataset
y_test = np.concatenate([y for x, y in val_ds], axis=0)
y_test = np.argmax(y_test, axis=1)
# Out:
# 155/155 [==============================] - 34s 222ms/step

# %%
# Print the classification report
print(classification_report(y_test, y_pred, target_names=["Dog", "Cat"], zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#          Dog       0.49      1.00      0.66      2429
#          Cat       1.00      0.00      0.00      2526
#
#     accuracy                           0.49      4955
#    macro avg       0.75      0.50      0.33      4955
# weighted avg       0.75      0.49      0.32      4955

# %% [markdown]
#               precision    recall  f1-score   support
#
#          Dog       0.49      1.00      0.66      2429
#          Cat       1.00      0.00      0.00      2526
#
#     accuracy                           0.49      4955
#    macro avg       0.75      0.50      0.33      4955
# weighted avg       0.75      0.49      0.32      4955

# %%
plt.plot(hist.history["loss"])
plt.plot(hist.history["val_loss"],'red')
plt.title("loss")
plt.show()

plt.plot(hist.history["accuracy"])
plt.plot(hist.history["val_accuracy"],'red')
plt.title("accuracy")
plt.show()

# %%
plt.plot(hist.history["accuracy"])
plt.plot(hist.history["val_accuracy"],'red')
plt.title("accuracy")
plt.show()
